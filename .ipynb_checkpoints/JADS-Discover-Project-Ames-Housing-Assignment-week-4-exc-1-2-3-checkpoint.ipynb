# %% [markdown]
# # Table of Contents - Ames Housing - Jan Deknatel - nov/dec 2020
#
# ### Assignment submission exercise 1-3  -  3-12-2020
#
# [Assignment](#Assignment)
#
# [Ames Housing Dataset Features](#Ames-Housing-Dataset-Features)
#
# [Exercise nr 1](#Exercise-nr-1)
#
# [Exercise nr 2](#Exercise-nr-2)
#
# [Exercise nr 3](#Exercise-nr-3)
#
#
#
# Referencing following Kaggle notebooks:
# - https://www.kaggle.com/leeclemmer/exploratory-data-analysis-of-housing-in-ames-iowa
# - https://www.kaggle.com/pmarcelino/comprehensive-data-exploration-with-python

# %% [markdown]
# # Assignment
#
# ![](https://storage.googleapis.com/kaggle-competitions/kaggle/5407/media/housesbanner.png)
#
# # Ames Housing dataset
#
# Following Kaggle's [Getting Started Prediction Competition](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview), the goal for this discover project is to predict the sales price for each house. For each Id in the test set, you must predict the value of the SalePrice variable.
#
# The performance metric for your prediction model is the _Root-Mean-Squared-Error (RMSE) between the logarithm of the predicted value and the logarithm of the observed sales price_. (Taking logs means that errors in predicting expensive houses and cheap houses will affect the result equally.)
#
# Looking at the [public leaderboard](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/leaderboard), the top 2% have RMSLE of 0.00044, whilst 25th-percentile and and median performance is at 0.125 and 0.14, respectively.
#
# As an extra challenge, you can try to trade-off the number of predictors (less is better) vs. performance. Can you make the top 10% (RMSLE 0.123) with the least number of predictors?
#
# ## Exercises
#
# ### Exercise 1
# Provide a table with descriptive statistics for all included variables and check:
#
#   - Classes of each of the variables (e.g. factors or continuous variables).
#   - Descriptive/summary statistics for all continuous variables (e.g. mean, SD, range) and factor variables (e.g. frequencies).
#   - Explore missing values
#
#
# ### Exercise 2
# There a several missing values in the dataset, which need to be tackled before we can proceed with the rest of the analysis. There are many ways to impute missing values, but for now, impute missing values as follows:
#
#   - Use the median for numeric variables
#   - Use the label "100" in all factor variables
#
# ### Exercise 3
# The variable "SalePrice" refers to the price at which a property was sold and hence is the variable of interest for our prediction model ("Y" or dependent variable). Explore Y in terms of:
#
#   - Descriptive/summary statistics (e.g. mean, SDs, range)
#   - Visualize the distribution of Y (e.g. matplotlib or seaborn)
#   - Visualize the distribution of Y by looking at various subgroups (e.g. create boxplot or scatterplot using matplotlib or seaborn)
#   - Look at differences between neigbourhoods
#   - Look at differences between housing style
#   - Draw a correlation plot to see all correlations between Y and the independent (numeric) variables (Hint: use df.plotting.scatter_matrix or seaborn.pairplot)
#
#
# ### Exercise 4
#
#   - Estimate a LASSO model and a kNN model
#   - Assess which model performs best

# %% [markdown]
# # Ames Housing Dataset Features

# %% [markdown]
# ### A couple of photos to get a feel for the houses

# %% [markdown]
# ![](https://raw.githubusercontent.com/knaat/Ames-housing/main/least_exp_house.jpg)
# Least expensive house (US$12,789) in Ames Housing dataset

# %% [markdown]
# ![](https://raw.githubusercontent.com/knaat/Ames-housing/main/most_exp_house.jpg)
# Most expensive house (US$755,000) in Ames Housing dataset

# %% [markdown]
# ### Description of 81 features
#
#
# 1.	1st Flr SF: First Floor square feet
# 2.	2nd Flr SF: Second floor square feet
# 3.	3-Ssn Porch: Three season porch area in square feet
# 4.	Alley: Type of alley access to property
# 5.	Bedroom: Bedrooms above grade (does NOT include basement bedrooms)
# 6.	Bldg Type: Type of dwelling
# 7.	Bsmt Cond: Evaluates the general condition of the basement
# 8.	Bsmt Exposure: Refers to walkout or garden level walls
# 9.	Bsmt Full Bath: Basement full bathrooms
# 10.	Bsmt Half Bath: Basement half bathrooms
# 11.	Bsmt Qual: Evaluates the height of the basement
# 12.	Bsmt Unf SF: Unfinished square feet of basement area
# 13.	BsmtFin SF 1: Type 1 finished square feet
# 14.	BsmtFin SF 2: Type 2 finished square feet
# 15.	BsmtFin Type 1: Rating of basement finished area
# 16.	BsmtFinType 2: Rating of basement finished area (if multiple types)
# 17.	Central Air: Central air conditioning
# 18.	Condition 1: Proximity to various conditions
# 19.	Condition 2: Proximity to various conditions (if more than one is present)
# 20.	Electrical: Electrical system
# 21.	Enclosed Porch: Enclosed porch area in square feet
# 22.	Exter Cond: Evaluates the present condition of the material on the exterior
# 23.	Exter Qual: Evaluates the quality of the material on the exterior
# 24.	Exterior 1: Exterior covering on house
# 25.	Exterior 2: Exterior covering on house (if more than one material)
# 26.	Fence: Fence quality
# 27.	FireplaceQu: Fireplace quality
# 28.	Fireplaces: Number of fireplaces
# 29.	Foundation: Type of foundation
# 30.	Full Bath: Full bathrooms above grade
# 31.	Functional: Home functionality (Assume typical unless deductions are warranted)
# 32.	Garage Area: Size of garage in square feet
# 33.	Garage Cars: Size of garage in car capacity
# 34.	Garage Cond: Garage condition
# 35.	Garage Finish: Interior finish of the garage
# 36.	Garage Qual: Garage quality
# 37.	Garage Type: Garage location
# 38.	Garage Yr Blt: Year garage was built
# 39.	Gr Liv Area: Above grade (ground) living area square feet
# 40.	Half Bath: Half baths above grade
# 41.	Heating: Type of heating
# 42.	HeatingQC: Heating quality and condition
# 43.	House Style: Style of dwelling
# 44.	Kitchen: Kitchens above grade
# 45.	KitchenQual: Kitchen quality
# 46.	Land Contour: Flatness of the property
# 47.	Land Slope: Slope of property
# 48.	Lot Area: Lot size in square feet
# 49.	Lot Config: Lot configuration
# 50.	Lot Frontage: Linear feet of street connected to property
# 51.	Lot Shape: General shape of property
# 52.	Low Qual Fin SF: Low quality finished square feet (all floors)
# 53.	Mas Vnr Area: Masonry veneer area in square feet
# 54.	Mas Vnr Type: Masonry veneer type
# 55.	Misc Feature: Miscellaneous feature not covered in other categories
# 56.	Misc Val: Value of miscellaneous feature
# 57.	Mo Sold: Month Sold
# 58.	MS SubClass: Identifies the type of dwelling involved in the sale.
# 59.	MS Zoning: Identifies the general zoning classification of the sale.
# 60.	Neighborhood: Physical locations within Ames city limits (map available)
# 61.	Open Porch SF: Open porch area in square feet
# 62.	Order: Observation number
# 63.	Overall Cond: Rates the overall condition of the house
# 64.	Overall Qual: Rates the overall material and finish of the house
# 65.	Paved Drive: Paved driveway
# 66.	PID: Parcel identification number - can be used with city web site for parcel review.
# 67.	Pool Area: Pool area in square feet
# 68.	Pool QC: Pool quality
# 69.	Roof Matl: Roof material
# 70.	Roof Style: Type of roof
# 71.	Sale Condition: Condition of sale
# 72.	Sale Type: Type of sale
# 73.	Screen Porch: Screen porch area in square feet
# 74.	Street: Type of road access to property
# 75.	Total Bsmt SF: Total square feet of basement area
# 76.	TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# 77.	Utilities: Type of utilities available
# 78.	Wood Deck SF: Wood deck area in square feet
# 79.	Year Built: Original construction date
# 80.	Year Remod/Add: Remodel date (same as construction date if no remodeling or additions)
# 81.	Yr Sold: Year Sold

# %% [markdown]
# ### Import libraries

# %%
import os
import warnings

import pandas as pd
print('\nUsing Pandas version\t',pd.__version__)

import numpy as np
print('Using Numpy version\t',np.version.version)

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
print('Using Matplotlib version',matplotlib.__version__)

import seaborn as sns
print('Using Seaborn version\t',sns.__version__)
# Out:
# Using Pandas version	 1.0.5
# Using Numpy version	 1.18.5
# Using Matplotlib version 3.2.2
# Using Seaborn version	 0.10.1

# %% [markdown]
# ### Ames housing data and photos in Beacon database

# %%
#
# Opens tab in Google Chrome and search page of current Ames housing database. 
# Use PID (=Parcel ID) from full Ames Housing dataset (not in train and test csv files) preceded by a zero(!) to
# search for a specific house. You can also directly open an aerial phot of the plot or a photo of the property
# by using next two example URL's for house with Parcel ID 0534403410 .
#
os.system('start chrome "https://beacon.schneidercorp.com/Application.aspx?AppID=165&LayerID=2145&PageTypeID=2&PageID=1104"')
# Out:
# 0

# %%
#
# Opens tab in Google Chrome and display information overview for house with PID 0534403410 from current Ames housing database.
# Replace Keyvalue key with other PID from full Ames Housing dataset (not in train and test csv files) to look at other houses. 
#
os.system('start chrome "https://beacon.schneidercorp.com/Application.aspx?AppID=165&LayerID=2145&PageTypeID=4&PageID=1108&Q=1323133603&KeyValue=0534403410"')
# Out:
# 0

# %%
#
# Opens tab in Google Chrome and display aerial photo example of current Ames housing database for house with PID 0534403410.
# Replace Keyvalue key with other PID from full Ames Housing dataset (not in train and test csv files) to look at other houses. 
#
os.system('start chrome "https://beacon.schneidercorp.com/Application.aspx?AppID=165&LayerID=2145&PageID=1108&KeyValue=0534403410"')
# Out:
# 0

# %% [markdown]
# # Exercise nr 1

# %% [markdown]
# ### Defining a function to explore a dataframe and return categorized lists of features¶

# %%
def expl_df(df_input, name):
    
    """ Prints analysis of dataframe 'df_input' with name 'name' and returns lists of numeric, categorical, complete,
        incomplete features, features with many zeros and features with high skew > 0.75. """

    print('\n\033[1mDataframe analysis for dataframe:  ',name,'\033[0m\n')

    # Print dimensions of dataframe
    num_rows = df_input.shape[0]
    num_cols = df_input.shape[1]
    print('Dataframe',name,'has', num_rows, 'rows and', num_cols,'columns\n')

    # Check which features are numeric and which features are categorical 
    num_features = list(df_input.select_dtypes(include=['int64','float64']).columns)
    cat_features = list(df_input.select_dtypes(include=['object', 'category']).columns)
    print('Dataframe',name,'has', len(num_features) , 'numeric features and', len(cat_features),'categorical features\n')

    # Check which features have missing values and might need attention and print number of features
    count_values_feature=df_input.count()

    complete_features = list(count_values_feature[count_values_feature == num_rows].index)
    incomplete_features = list(count_values_feature[count_values_feature < num_rows].index)
    print('Dataframe',name,'has',len(complete_features), 'complete features and', len(incomplete_features),'incomplete features\n')
    
    # Check which features have more than 50% zero values and print number of features
    zeroes_feature = (df_input[num_features] == 0).sum() / num_rows
    high_zero_features = list(zeroes_feature[zeroes_feature > 0.5].index)
    print('Dataframe',name,'has',len(high_zero_features), 'features with more than 50% zeroes\n')

    # Calculate skew for each numeric feature and select features with skew>0.75 
    calc_skew_feature = df_input[num_features].skew()
    skew_features = list(calc_skew_feature[calc_skew_feature > 0.75].index)
    print('Dataframe',name,'has',len(skew_features), 'numeric features with a skew > 0.75\n')
    
    return num_features, cat_features, incomplete_features, complete_features, high_zero_features, skew_features

# %% [markdown]
# ### Import full dataset in csv format

# %%
#
# Read full Ames housing dataset and drop columns 'Order' and 'PID'
#

df = pd.read_csv("https://raw.githubusercontent.com/knaat/Ames-housing/main/AmesHousing.csv")

df.drop(columns=['Order', 'PID'], inplace=True)

# %% [markdown]
# ### Inspect data frame shape, feature names, number of non-null values  and column datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 80 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MS SubClass      2930 non-null   int64
#  1   MS Zoning        2930 non-null   object
#  2   Lot Frontage     2440 non-null   float64
#  3   Lot Area         2930 non-null   int64
#  4   Street           2930 non-null   object
#  5   Alley            198 non-null    object
#  6   Lot Shape        2930 non-null   object
#  7   Land Contour     2930 non-null   object
#  8   Utilities        2930 non-null   object
#  9   Lot Config       2930 non-null   object
#  10  Land Slope       2930 non-null   object
#  11  Neighborhood     2930 non-null   object
#  12  Condition 1      2930 non-null   object
#  13  Condition 2      2930 non-null   object
#  14  Bldg Type        2930 non-null   object
#  15  House Style      2930 non-null   object
#  16  Overall Qual     2930 non-null   int64
#  17  Overall Cond     2930 non-null   int64
#  18  Year Built       2930 non-null   int64
#  19  Year Remod/Add   2930 non-null   int64
#  20  Roof Style       2930 non-null   object
#  21  Roof Matl        2930 non-null   object
#  22  Exterior 1st     2930 non-null   object
#  23  Exterior 2nd     2930 non-null   object
#  24  Mas Vnr Type     2907 non-null   object
#  25  Mas Vnr Area     2907 non-null   float64
#  26  Exter Qual       2930 non-null   object
#  27  Exter Cond       2930 non-null   object
#  28  Foundation       2930 non-null   object
#  29  Bsmt Qual        2850 non-null   object
#  30  Bsmt Cond        2850 non-null   object
#  31  Bsmt Exposure    2847 non-null   object
#  32  BsmtFin Type 1   2850 non-null   object
#  33  BsmtFin SF 1     2929 non-null   float64
#  34  BsmtFin Type 2   2849 non-null   object
#  35  BsmtFin SF 2     2929 non-null   float64
#  36  Bsmt Unf SF      2929 non-null   float64
#  37  Total Bsmt SF    2929 non-null   float64
#  38  Heating          2930 non-null   object
#  39  Heating QC       2930 non-null   object
#  40  Central Air      2930 non-null   object
#  41  Electrical       2929 non-null   object
#  42  1st Flr SF       2930 non-null   int64
#  43  2nd Flr SF       2930 non-null   int64
#  44  Low Qual Fin SF  2930 non-null   int64
#  45  Gr Liv Area      2930 non-null   int64
#  46  Bsmt Full Bath   2928 non-null   float64
#  47  Bsmt Half Bath   2928 non-null   float64
#  48  Full Bath        2930 non-null   int64
#  49  Half Bath        2930 non-null   int64
#  50  Bedroom AbvGr    2930 non-null   int64
#  51  Kitchen AbvGr    2930 non-null   int64
#  52  Kitchen Qual     2930 non-null   object
#  53  TotRms AbvGrd    2930 non-null   int64
#  54  Functional       2930 non-null   object
#  55  Fireplaces       2930 non-null   int64
#  56  Fireplace Qu     1508 non-null   object
#  57  Garage Type      2773 non-null   object
#  58  Garage Yr Blt    2771 non-null   float64
#  59  Garage Finish    2771 non-null   object
#  60  Garage Cars      2929 non-null   float64
#  61  Garage Area      2929 non-null   float64
#  62  Garage Qual      2771 non-null   object
#  63  Garage Cond      2771 non-null   object
#  64  Paved Drive      2930 non-null   object
#  65  Wood Deck SF     2930 non-null   int64
#  66  Open Porch SF    2930 non-null   int64
#  67  Enclosed Porch   2930 non-null   int64
#  68  3Ssn Porch       2930 non-null   int64
#  69  Screen Porch     2930 non-null   int64
#  70  Pool Area        2930 non-null   int64
#  71  Pool QC          13 non-null     object
#  72  Fence            572 non-null    object
#  73  Misc Feature     106 non-null    object
#  74  Misc Val         2930 non-null   int64
#  75  Mo Sold          2930 non-null   int64
#  76  Yr Sold          2930 non-null   int64
#  77  Sale Type        2930 non-null   object
#  78  Sale Condition   2930 non-null   object
#  79  SalePrice        2930 non-null   int64
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.8+ MB

# %%
#
# Call defined function which explores dataframe df and returns feature lists 
#
num_feat,cat_feat,incomp_feat,comp_feat,hi_0_feat,skew_feat = expl_df(df,'df')
# Out:
# Dataframe analysis for dataframe:   df
#
# Dataframe df has 2930 rows and 80 columns
#
# Dataframe df has 37 numeric features and 43 categorical features
#
# Dataframe df has 53 complete features and 27 incomplete features
#
# Dataframe df has 13 features with more than 50% zeroes
#
# Dataframe df has 23 numeric features with a skew > 0.75

# %% [markdown]
# ### Descriptive/summary statistics for all numeric variables

# %%
#
# Set option for pandas table printing
#
pd.set_option("display.max.columns", None)
pd.set_option("display.max.rows", None)

# %%
df.describe().transpose()
# Out:
#                   count           mean           std      min        25%  \
# MS SubClass      2930.0      57.387372     42.638025     20.0      20.00
# Lot Frontage     2440.0      69.224590     23.365335     21.0      58.00
# Lot Area         2930.0   10147.921843   7880.017759   1300.0    7440.25
# Overall Qual     2930.0       6.094881      1.411026      1.0       5.00
# Overall Cond     2930.0       5.563140      1.111537      1.0       5.00
# Year Built       2930.0    1971.356314     30.245361   1872.0    1954.00
# Year Remod/Add   2930.0    1984.266553     20.860286   1950.0    1965.00
# Mas Vnr Area     2907.0     101.896801    179.112611      0.0       0.00
# BsmtFin SF 1     2929.0     442.629566    455.590839      0.0       0.00
# BsmtFin SF 2     2929.0      49.722431    169.168476      0.0       0.00
# Bsmt Unf SF      2929.0     559.262547    439.494153      0.0     219.00
# Total Bsmt SF    2929.0    1051.614544    440.615067      0.0     793.00
# 1st Flr SF       2930.0    1159.557679    391.890885    334.0     876.25
# 2nd Flr SF       2930.0     335.455973    428.395715      0.0       0.00
# Low Qual Fin SF  2930.0       4.676792     46.310510      0.0       0.00
# Gr Liv Area      2930.0    1499.690444    505.508887    334.0    1126.00
# Bsmt Full Bath   2928.0       0.431352      0.524820      0.0       0.00
# Bsmt Half Bath   2928.0       0.061134      0.245254      0.0       0.00
# Full Bath        2930.0       1.566553      0.552941      0.0       1.00
# Half Bath        2930.0       0.379522      0.502629      0.0       0.00
# Bedroom AbvGr    2930.0       2.854266      0.827731      0.0       2.00
# Kitchen AbvGr    2930.0       1.044369      0.214076      0.0       1.00
# TotRms AbvGrd    2930.0       6.443003      1.572964      2.0       5.00
# Fireplaces       2930.0       0.599317      0.647921      0.0       0.00
# Garage Yr Blt    2771.0    1978.132443     25.528411   1895.0    1960.00
# Garage Cars      2929.0       1.766815      0.760566      0.0       1.00
# Garage Area      2929.0     472.819734    215.046549      0.0     320.00
# Wood Deck SF     2930.0      93.751877    126.361562      0.0       0.00
# Open Porch SF    2930.0      47.533447     67.483400      0.0       0.00
# Enclosed Porch   2930.0      23.011604     64.139059      0.0       0.00
# 3Ssn Porch       2930.0       2.592491     25.141331      0.0       0.00
# Screen Porch     2930.0      16.002048     56.087370      0.0       0.00
# Pool Area        2930.0       2.243345     35.597181      0.0       0.00
# Misc Val         2930.0      50.635154    566.344288      0.0       0.00
# Mo Sold          2930.0       6.216041      2.714492      1.0       4.00
# Yr Sold          2930.0    2007.790444      1.316613   2006.0    2007.00
# SalePrice        2930.0  180796.060068  79886.692357  12789.0  129500.00
#
#                       50%        75%       max
# MS SubClass          50.0      70.00     190.0
# Lot Frontage         68.0      80.00     313.0
# Lot Area           9436.5   11555.25  215245.0
# Overall Qual          6.0       7.00      10.0
# Overall Cond          5.0       6.00       9.0
# Year Built         1973.0    2001.00    2010.0
# Year Remod/Add     1993.0    2004.00    2010.0
# Mas Vnr Area          0.0     164.00    1600.0
# BsmtFin SF 1        370.0     734.00    5644.0
# BsmtFin SF 2          0.0       0.00    1526.0
# Bsmt Unf SF         466.0     802.00    2336.0
# Total Bsmt SF       990.0    1302.00    6110.0
# 1st Flr SF         1084.0    1384.00    5095.0
# 2nd Flr SF            0.0     703.75    2065.0
# Low Qual Fin SF       0.0       0.00    1064.0
# Gr Liv Area        1442.0    1742.75    5642.0
# Bsmt Full Bath        0.0       1.00       3.0
# Bsmt Half Bath        0.0       0.00       2.0
# Full Bath             2.0       2.00       4.0
# Half Bath             0.0       1.00       2.0
# Bedroom AbvGr         3.0       3.00       8.0
# Kitchen AbvGr         1.0       1.00       3.0
# TotRms AbvGrd         6.0       7.00      15.0
# Fireplaces            1.0       1.00       4.0
# Garage Yr Blt      1979.0    2002.00    2207.0
# Garage Cars           2.0       2.00       5.0
# Garage Area         480.0     576.00    1488.0
# Wood Deck SF          0.0     168.00    1424.0
# Open Porch SF        27.0      70.00     742.0
# Enclosed Porch        0.0       0.00    1012.0
# 3Ssn Porch            0.0       0.00     508.0
# Screen Porch          0.0       0.00     576.0
# Pool Area             0.0       0.00     800.0
# Misc Val              0.0       0.00   17000.0
# Mo Sold               6.0       8.00      12.0
# Yr Sold            2008.0    2009.00    2010.0
# SalePrice        160000.0  213500.00  755000.0

# %%
#
# Make histograms of a couple interesting numeric features 
#
for column in ['SalePrice', 'Lot Area', 'Lot Frontage', 'Year Built', 'Year Remod/Add', 'Gr Liv Area', '1st Flr SF']:
    df[column].hist(bins=100, rwidth=.8, figsize=(14,4))
    plt.title(column)
    plt.show()

# %% [markdown]
# ### Define a function to create space-efficient way to plot 1D histograms for all remaining numeric variables

# %%
#
# 1D histogram plots for all numeric features in dataframe without features in list
# 'list_of_features_to_be_dropped' sorted by feature name 
#

def plt_1D_histograms_for_dataframe_numeric_features(dataframe, list_of_features_to_be_dropped):

    """ Plot 1D histogram plots for all numerical features in pandas dataframe sorted by feature name """

    # Create list with Numerical Features of dataframe
    numeric_features = dataframe.select_dtypes(include=['int64','float64']).columns

    # Drop features as per list_of_features_to_be_dropped and convert to list
    if len(list_of_features_to_be_dropped) > 0:
        numeric_features = list(numeric_features.drop(list_of_features_to_be_dropped))
    
    # Calculate number of plots per column
    num_plt_cols = len(numeric_features)
    first_num_plt_cols = num_plt_cols - int(num_plt_cols/2)

    # Create subplots in 2 columns
    fig, axes = plt.subplots(first_num_plt_cols, 2, figsize=(16,first_num_plt_cols))

    # Create subplots in first column
    i=0
    for column in numeric_features[0:first_num_plt_cols]:
        dataframe[column].dropna(inplace=True)
        bins = np.histogram(dataframe[column], bins=100)[0]
        bins = np.expand_dims(bins, axis=0)
        axes[i,0].imshow(bins, cmap='YlOrRd', aspect='auto')
        axes[i,0].get_xaxis().set_visible(False)
        axes[i,0].get_yaxis().set_visible(False)
        axes[i,0].set_title(str(column), loc='left')
        i = i+1

    # Create subplots in second column
    i=0
    for column in numeric_features[first_num_plt_cols:num_plt_cols]:
        dataframe[column].dropna(inplace=True)
        bins = np.histogram(dataframe[column], bins=100)[0]
        bins = np.expand_dims(bins, axis=0)
        axes[i,1].imshow(bins, cmap='YlOrRd', aspect='auto')
        axes[i,1].get_xaxis().set_visible(False)
        axes[i,1].get_yaxis().set_visible(False)
        axes[i,1].set_title(str(column), loc='left')
        i = i+1

    plt.tight_layout()
    plt.show()
    return

# %%
#
# Plot 1D histograms for all numeric features with defined function 
#
plt_1D_histograms_for_dataframe_numeric_features(df,[])

# %%
#
# Grid of seaborn distribution plots of all numerical features visualising distributions of numeric features in a different way
#  N.B. In version 0.11 of Seaborn pd.melt is not required anymore. A new plot routine to plot distribution grid is included.  
#

# Switch off warnings to avoid annoying warnings
warnings.filterwarnings('ignore')

df_melted_num = pd.melt(df, value_vars=num_feat)
facet_grid = sns.FacetGrid(df_melted_num, col='variable', col_wrap=4, sharex=False, sharey=False)
facet_grid = facet_grid.map(sns.distplot, 'value')

# Switch on warnings again
warnings.filterwarnings('default')

# %%
#
# Grid of box plots of all numerical features
#

# Switch off warnings to avoid annoying warnings
warnings.filterwarnings('ignore')

facet_grid = sns.FacetGrid(df_melted_num, col='variable', col_wrap=4, sharex=False, sharey=False)
facet_grid = facet_grid.map(sns.boxplot, 'value')

# Switch on warnings again
warnings.filterwarnings('default')

# %% [markdown]
# ### Descriptive/summary statistics for categorical variables

# %%
df.describe(include='all').transpose()
# Out:
#                 count unique      top  freq       mean       std    min  \
# MS SubClass      2930    NaN      NaN   NaN    57.3874    42.638     20
# MS Zoning        2930      7       RL  2273        NaN       NaN    NaN
# Lot Frontage     2440    NaN      NaN   NaN    69.2246   23.3653     21
# Lot Area         2930    NaN      NaN   NaN    10147.9   7880.02   1300
# Street           2930      2     Pave  2918        NaN       NaN    NaN
# Alley             198      2     Grvl   120        NaN       NaN    NaN
# Lot Shape        2930      4      Reg  1859        NaN       NaN    NaN
# Land Contour     2930      4      Lvl  2633        NaN       NaN    NaN
# Utilities        2930      3   AllPub  2927        NaN       NaN    NaN
# Lot Config       2930      5   Inside  2140        NaN       NaN    NaN
# Land Slope       2930      3      Gtl  2789        NaN       NaN    NaN
# Neighborhood     2930     28    NAmes   443        NaN       NaN    NaN
# Condition 1      2930      9     Norm  2522        NaN       NaN    NaN
# Condition 2      2930      8     Norm  2900        NaN       NaN    NaN
# Bldg Type        2930      5     1Fam  2425        NaN       NaN    NaN
# House Style      2930      8   1Story  1481        NaN       NaN    NaN
# Overall Qual     2930    NaN      NaN   NaN    6.09488   1.41103      1
# Overall Cond     2930    NaN      NaN   NaN    5.56314   1.11154      1
# Year Built       2930    NaN      NaN   NaN    1971.36   30.2454   1872
# Year Remod/Add   2930    NaN      NaN   NaN    1984.27   20.8603   1950
# Roof Style       2930      6    Gable  2321        NaN       NaN    NaN
# Roof Matl        2930      8  CompShg  2887        NaN       NaN    NaN
# Exterior 1st     2930     16  VinylSd  1026        NaN       NaN    NaN
# Exterior 2nd     2930     17  VinylSd  1015        NaN       NaN    NaN
# Mas Vnr Type     2907      5     None  1752        NaN       NaN    NaN
# Mas Vnr Area     2907    NaN      NaN   NaN    101.897   179.113      0
# Exter Qual       2930      4       TA  1799        NaN       NaN    NaN
# Exter Cond       2930      5       TA  2549        NaN       NaN    NaN
# Foundation       2930      6    PConc  1310        NaN       NaN    NaN
# Bsmt Qual        2850      5       TA  1283        NaN       NaN    NaN
# Bsmt Cond        2850      5       TA  2616        NaN       NaN    NaN
# Bsmt Exposure    2847      4       No  1906        NaN       NaN    NaN
# BsmtFin Type 1   2850      6      GLQ   859        NaN       NaN    NaN
# BsmtFin SF 1     2929    NaN      NaN   NaN     442.63   455.591      0
# BsmtFin Type 2   2849      6      Unf  2499        NaN       NaN    NaN
# BsmtFin SF 2     2929    NaN      NaN   NaN    49.7224   169.168      0
# Bsmt Unf SF      2929    NaN      NaN   NaN    559.263   439.494      0
# Total Bsmt SF    2929    NaN      NaN   NaN    1051.61   440.615      0
# Heating          2930      6     GasA  2885        NaN       NaN    NaN
# Heating QC       2930      5       Ex  1495        NaN       NaN    NaN
# Central Air      2930      2        Y  2734        NaN       NaN    NaN
# Electrical       2929      5    SBrkr  2682        NaN       NaN    NaN
# 1st Flr SF       2930    NaN      NaN   NaN    1159.56   391.891    334
# 2nd Flr SF       2930    NaN      NaN   NaN    335.456   428.396      0
# Low Qual Fin SF  2930    NaN      NaN   NaN    4.67679   46.3105      0
# Gr Liv Area      2930    NaN      NaN   NaN    1499.69   505.509    334
# Bsmt Full Bath   2928    NaN      NaN   NaN   0.431352   0.52482      0
# Bsmt Half Bath   2928    NaN      NaN   NaN  0.0611339  0.245254      0
# Full Bath        2930    NaN      NaN   NaN    1.56655  0.552941      0
# Half Bath        2930    NaN      NaN   NaN   0.379522  0.502629      0
# Bedroom AbvGr    2930    NaN      NaN   NaN    2.85427  0.827731      0
# Kitchen AbvGr    2930    NaN      NaN   NaN    1.04437  0.214076      0
# Kitchen Qual     2930      5       TA  1494        NaN       NaN    NaN
# TotRms AbvGrd    2930    NaN      NaN   NaN      6.443   1.57296      2
# Functional       2930      8      Typ  2728        NaN       NaN    NaN
# Fireplaces       2930    NaN      NaN   NaN   0.599317  0.647921      0
# Fireplace Qu     1508      5       Gd   744        NaN       NaN    NaN
# Garage Type      2773      6   Attchd  1731        NaN       NaN    NaN
# Garage Yr Blt    2771    NaN      NaN   NaN    1978.13   25.5284   1895
# Garage Finish    2771      3      Unf  1231        NaN       NaN    NaN
# Garage Cars      2929    NaN      NaN   NaN    1.76681  0.760566      0
# Garage Area      2929    NaN      NaN   NaN     472.82   215.047      0
# Garage Qual      2771      5       TA  2615        NaN       NaN    NaN
# Garage Cond      2771      5       TA  2665        NaN       NaN    NaN
# Paved Drive      2930      3        Y  2652        NaN       NaN    NaN
# Wood Deck SF     2930    NaN      NaN   NaN    93.7519   126.362      0
# Open Porch SF    2930    NaN      NaN   NaN    47.5334   67.4834      0
# Enclosed Porch   2930    NaN      NaN   NaN    23.0116   64.1391      0
# 3Ssn Porch       2930    NaN      NaN   NaN    2.59249   25.1413      0
# Screen Porch     2930    NaN      NaN   NaN     16.002   56.0874      0
# Pool Area        2930    NaN      NaN   NaN    2.24334   35.5972      0
# Pool QC            13      4       Ex     4        NaN       NaN    NaN
# Fence             572      4    MnPrv   330        NaN       NaN    NaN
# Misc Feature      106      5     Shed    95        NaN       NaN    NaN
# Misc Val         2930    NaN      NaN   NaN    50.6352   566.344      0
# Mo Sold          2930    NaN      NaN   NaN    6.21604   2.71449      1
# Yr Sold          2930    NaN      NaN   NaN    2007.79   1.31661   2006
# Sale Type        2930     10      WD   2536        NaN       NaN    NaN
# Sale Condition   2930      6   Normal  2413        NaN       NaN    NaN
# SalePrice        2930    NaN      NaN   NaN     180796   79886.7  12789
#
#                      25%     50%      75%     max
# MS SubClass           20      50       70     190
# MS Zoning            NaN     NaN      NaN     NaN
# Lot Frontage          58      68       80     313
# Lot Area         7440.25  9436.5  11555.2  215245
# Street               NaN     NaN      NaN     NaN
# Alley                NaN     NaN      NaN     NaN
# Lot Shape            NaN     NaN      NaN     NaN
# Land Contour         NaN     NaN      NaN     NaN
# Utilities            NaN     NaN      NaN     NaN
# Lot Config           NaN     NaN      NaN     NaN
# Land Slope           NaN     NaN      NaN     NaN
# Neighborhood         NaN     NaN      NaN     NaN
# Condition 1          NaN     NaN      NaN     NaN
# Condition 2          NaN     NaN      NaN     NaN
# Bldg Type            NaN     NaN      NaN     NaN
# House Style          NaN     NaN      NaN     NaN
# Overall Qual           5       6        7      10
# Overall Cond           5       5        6       9
# Year Built          1954    1973     2001    2010
# Year Remod/Add      1965    1993     2004    2010
# Roof Style           NaN     NaN      NaN     NaN
# Roof Matl            NaN     NaN      NaN     NaN
# Exterior 1st         NaN     NaN      NaN     NaN
# Exterior 2nd         NaN     NaN      NaN     NaN
# Mas Vnr Type         NaN     NaN      NaN     NaN
# Mas Vnr Area           0       0      164    1600
# Exter Qual           NaN     NaN      NaN     NaN
# Exter Cond           NaN     NaN      NaN     NaN
# Foundation           NaN     NaN      NaN     NaN
# Bsmt Qual            NaN     NaN      NaN     NaN
# Bsmt Cond            NaN     NaN      NaN     NaN
# Bsmt Exposure        NaN     NaN      NaN     NaN
# BsmtFin Type 1       NaN     NaN      NaN     NaN
# BsmtFin SF 1           0     370      734    5644
# BsmtFin Type 2       NaN     NaN      NaN     NaN
# BsmtFin SF 2           0       0        0    1526
# Bsmt Unf SF          219     466      802    2336
# Total Bsmt SF        793     990     1302    6110
# Heating              NaN     NaN      NaN     NaN
# Heating QC           NaN     NaN      NaN     NaN
# Central Air          NaN     NaN      NaN     NaN
# Electrical           NaN     NaN      NaN     NaN
# 1st Flr SF        876.25    1084     1384    5095
# 2nd Flr SF             0       0   703.75    2065
# Low Qual Fin SF        0       0        0    1064
# Gr Liv Area         1126    1442  1742.75    5642
# Bsmt Full Bath         0       0        1       3
# Bsmt Half Bath         0       0        0       2
# Full Bath              1       2        2       4
# Half Bath              0       0        1       2
# Bedroom AbvGr          2       3        3       8
# Kitchen AbvGr          1       1        1       3
# Kitchen Qual         NaN     NaN      NaN     NaN
# TotRms AbvGrd          5       6        7      15
# Functional           NaN     NaN      NaN     NaN
# Fireplaces             0       1        1       4
# Fireplace Qu         NaN     NaN      NaN     NaN
# Garage Type          NaN     NaN      NaN     NaN
# Garage Yr Blt       1960    1979     2002    2207
# Garage Finish        NaN     NaN      NaN     NaN
# Garage Cars            1       2        2       5
# Garage Area          320     480      576    1488
# Garage Qual          NaN     NaN      NaN     NaN
# Garage Cond          NaN     NaN      NaN     NaN
# Paved Drive          NaN     NaN      NaN     NaN
# Wood Deck SF           0       0      168    1424
# Open Porch SF          0      27       70     742
# Enclosed Porch         0       0        0    1012
# 3Ssn Porch             0       0        0     508
# Screen Porch           0       0        0     576
# Pool Area              0       0        0     800
# Pool QC              NaN     NaN      NaN     NaN
# Fence                NaN     NaN      NaN     NaN
# Misc Feature         NaN     NaN      NaN     NaN
# Misc Val               0       0        0   17000
# Mo Sold                4       6        8      12
# Yr Sold             2007    2008     2009    2010
# Sale Type            NaN     NaN      NaN     NaN
# Sale Condition       NaN     NaN      NaN     NaN
# SalePrice         129500  160000   213500  755000

# %%
#
# Change datatype from object to categorical for all columns in 'cat_feat' list.
#
for column in cat_feat:
    df[column] = pd.Categorical(df[column])

# %%
#
# Pandas histogram plots for all categorical features
#
for column in cat_feat:
    print('\nHistogram for column', column)
    df[column].value_counts().plot(kind='bar', figsize=(12,4))
    plt.show()
# Out:
# Histogram for column MS Zoning
# Histogram for column Street
# Histogram for column Alley
# Histogram for column Lot Shape
# Histogram for column Land Contour
# Histogram for column Utilities
# Histogram for column Lot Config
# Histogram for column Land Slope
# Histogram for column Neighborhood
# Histogram for column Condition 1
# Histogram for column Condition 2
# Histogram for column Bldg Type
# Histogram for column House Style
# Histogram for column Roof Style
# Histogram for column Roof Matl
# Histogram for column Exterior 1st
# Histogram for column Exterior 2nd
# Histogram for column Mas Vnr Type
# Histogram for column Exter Qual
# Histogram for column Exter Cond
# Histogram for column Foundation
# Histogram for column Bsmt Qual
# Histogram for column Bsmt Cond
# Histogram for column Bsmt Exposure
# Histogram for column BsmtFin Type 1
# Histogram for column BsmtFin Type 2
# Histogram for column Heating
# Histogram for column Heating QC
# Histogram for column Central Air
# Histogram for column Electrical
# Histogram for column Kitchen Qual
# Histogram for column Functional
# Histogram for column Fireplace Qu
# Histogram for column Garage Type
# Histogram for column Garage Finish
# Histogram for column Garage Qual
# Histogram for column Garage Cond
# Histogram for column Paved Drive
# Histogram for column Pool QC
# Histogram for column Fence
# Histogram for column Misc Feature
# Histogram for column Sale Type
# Histogram for column Sale Condition

# %%
#
# Distribution plots of all categorical features in more efficient grid 
#

# Switch off warnings to avoid annoying warnings
warnings.filterwarnings('ignore')

df_melted_cat = pd.melt(df, value_vars=sorted(cat_feat))
facet_grid = sns.FacetGrid(df_melted_cat, col='variable', col_wrap=4, sharex=False, sharey=False)
facet_grid = facet_grid.map(sns.countplot, 'value')

# Plot x-labels rotated by 60 degrees to make them readable
for ax in facet_grid.axes.flat:
    plt.setp(ax.get_xticklabels(), rotation=60)
facet_grid.fig.tight_layout()
plt.show()

# Switch on warnings again
warnings.filterwarnings('default')

# %% [markdown]
# ### Explore Missing Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 80 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MS SubClass      2930 non-null   int64
#  1   MS Zoning        2930 non-null   category
#  2   Lot Frontage     2440 non-null   float64
#  3   Lot Area         2930 non-null   int64
#  4   Street           2930 non-null   category
#  5   Alley            198 non-null    category
#  6   Lot Shape        2930 non-null   category
#  7   Land Contour     2930 non-null   category
#  8   Utilities        2930 non-null   category
#  9   Lot Config       2930 non-null   category
#  10  Land Slope       2930 non-null   category
#  11  Neighborhood     2930 non-null   category
#  12  Condition 1      2930 non-null   category
#  13  Condition 2      2930 non-null   category
#  14  Bldg Type        2930 non-null   category
#  15  House Style      2930 non-null   category
#  16  Overall Qual     2930 non-null   int64
#  17  Overall Cond     2930 non-null   int64
#  18  Year Built       2930 non-null   int64
#  19  Year Remod/Add   2930 non-null   int64
#  20  Roof Style       2930 non-null   category
#  21  Roof Matl        2930 non-null   category
#  22  Exterior 1st     2930 non-null   category
#  23  Exterior 2nd     2930 non-null   category
#  24  Mas Vnr Type     2907 non-null   category
#  25  Mas Vnr Area     2907 non-null   float64
#  26  Exter Qual       2930 non-null   category
#  27  Exter Cond       2930 non-null   category
#  28  Foundation       2930 non-null   category
#  29  Bsmt Qual        2850 non-null   category
#  30  Bsmt Cond        2850 non-null   category
#  31  Bsmt Exposure    2847 non-null   category
#  32  BsmtFin Type 1   2850 non-null   category
#  33  BsmtFin SF 1     2929 non-null   float64
#  34  BsmtFin Type 2   2849 non-null   category
#  35  BsmtFin SF 2     2929 non-null   float64
#  36  Bsmt Unf SF      2929 non-null   float64
#  37  Total Bsmt SF    2929 non-null   float64
#  38  Heating          2930 non-null   category
#  39  Heating QC       2930 non-null   category
#  40  Central Air      2930 non-null   category
#  41  Electrical       2929 non-null   category
#  42  1st Flr SF       2930 non-null   int64
#  43  2nd Flr SF       2930 non-null   int64
#  44  Low Qual Fin SF  2930 non-null   int64
#  45  Gr Liv Area      2930 non-null   int64
#  46  Bsmt Full Bath   2928 non-null   float64
#  47  Bsmt Half Bath   2928 non-null   float64
#  48  Full Bath        2930 non-null   int64
#  49  Half Bath        2930 non-null   int64
#  50  Bedroom AbvGr    2930 non-null   int64
#  51  Kitchen AbvGr    2930 non-null   int64
#  52  Kitchen Qual     2930 non-null   category
#  53  TotRms AbvGrd    2930 non-null   int64
#  54  Functional       2930 non-null   category
#  55  Fireplaces       2930 non-null   int64
#  56  Fireplace Qu     1508 non-null   category
#  57  Garage Type      2773 non-null   category
#  58  Garage Yr Blt    2771 non-null   float64
#  59  Garage Finish    2771 non-null   category
#  60  Garage Cars      2929 non-null   float64
#  61  Garage Area      2929 non-null   float64
#  62  Garage Qual      2771 non-null   category
#  63  Garage Cond      2771 non-null   category
#  64  Paved Drive      2930 non-null   category
#  65  Wood Deck SF     2930 non-null   int64
#  66  Open Porch SF    2930 non-null   int64
#  67  Enclosed Porch   2930 non-null   int64
#  68  3Ssn Porch       2930 non-null   int64
#  69  Screen Porch     2930 non-null   int64
#  70  Pool Area        2930 non-null   int64
#  71  Pool QC          13 non-null     category
#  72  Fence            572 non-null    category
#  73  Misc Feature     106 non-null    category
#  74  Misc Val         2930 non-null   int64
#  75  Mo Sold          2930 non-null   int64
#  76  Yr Sold          2930 non-null   int64
#  77  Sale Type        2930 non-null   category
#  78  Sale Condition   2930 non-null   category
#  79  SalePrice        2930 non-null   int64
# dtypes: category(43), float64(11), int64(26)
# memory usage: 981.5 KB

# %%
#
# Check each feature in list 'incomp_feat' and print datatype and number of missing values
#
for column in incomp_feat:
    print('Column\t', column, '\thas dataype', df[column].dtype,'\tand has', df.shape[0]-df[column].count(),'missing values')
# Out:
# Column	 Lot Frontage 	has dataype float64 	and has 490 missing values
# Column	 Alley 	has dataype category 	and has 2732 missing values
# Column	 Mas Vnr Type 	has dataype category 	and has 23 missing values
# Column	 Mas Vnr Area 	has dataype float64 	and has 23 missing values
# Column	 Bsmt Qual 	has dataype category 	and has 80 missing values
# Column	 Bsmt Cond 	has dataype category 	and has 80 missing values
# Column	 Bsmt Exposure 	has dataype category 	and has 83 missing values
# Column	 BsmtFin Type 1 	has dataype category 	and has 80 missing values
# Column	 BsmtFin SF 1 	has dataype float64 	and has 1 missing values
# Column	 BsmtFin Type 2 	has dataype category 	and has 81 missing values
# Column	 BsmtFin SF 2 	has dataype float64 	and has 1 missing values
# Column	 Bsmt Unf SF 	has dataype float64 	and has 1 missing values
# Column	 Total Bsmt SF 	has dataype float64 	and has 1 missing values
# Column	 Electrical 	has dataype category 	and has 1 missing values
# Column	 Bsmt Full Bath 	has dataype float64 	and has 2 missing values
# Column	 Bsmt Half Bath 	has dataype float64 	and has 2 missing values
# Column	 Fireplace Qu 	has dataype category 	and has 1422 missing values
# Column	 Garage Type 	has dataype category 	and has 157 missing values
# Column	 Garage Yr Blt 	has dataype float64 	and has 159 missing values
# Column	 Garage Finish 	has dataype category 	and has 159 missing values
# Column	 Garage Cars 	has dataype float64 	and has 1 missing values
# Column	 Garage Area 	has dataype float64 	and has 1 missing values
# Column	 Garage Qual 	has dataype category 	and has 159 missing values
# Column	 Garage Cond 	has dataype category 	and has 159 missing values
# Column	 Pool QC 	has dataype category 	and has 2917 missing values
# Column	 Fence 	has dataype category 	and has 2358 missing values
# Column	 Misc Feature 	has dataype category 	and has 2824 missing values

# %% [markdown]
# # Exercise nr 2

# %% [markdown]
# ### Replace Missing Values

# %%
#
# Replace missing values with "missing" in the categorical features and with median in numeric features
#
for column in incomp_feat:
    if (str(df[column].dtype) == "category") | (str(df[column].dtype) == "object"):
        print('Fixing categorical feature:\t', column, '\tby replacing missing values with label "missing"')

        try:
            df[column] = df[column].cat.add_categories('missing') # add "missing" to categories before replacing 
        except:
            continue # "missing" was already a category for categorical features

        df[column].fillna('missing', inplace = True) 
    elif (str(df[column].dtype) == "int64") | (str(df[column].dtype) == "float64"):
        print('Fixing numeric feature:', column,'\tby replacing missing values with median:\t', df[column].median())
        df[column].fillna(df[column].median(), inplace=True)
    
    else:
        print('\nUnexpected datatype for feature\n', column)
# Out:
# Fixing numeric feature: Lot Frontage 	by replacing missing values with median:	 68.0
# Fixing categorical feature:	 Alley 	by replacing missing values with label "missing"
# Fixing categorical feature:	 Mas Vnr Type 	by replacing missing values with label "missing"
# Fixing numeric feature: Mas Vnr Area 	by replacing missing values with median:	 0.0
# Fixing categorical feature:	 Bsmt Qual 	by replacing missing values with label "missing"
# Fixing categorical feature:	 Bsmt Cond 	by replacing missing values with label "missing"
# Fixing categorical feature:	 Bsmt Exposure 	by replacing missing values with label "missing"
# Fixing categorical feature:	 BsmtFin Type 1 	by replacing missing values with label "missing"
# Fixing numeric feature: BsmtFin SF 1 	by replacing missing values with median:	 370.0
# Fixing categorical feature:	 BsmtFin Type 2 	by replacing missing values with label "missing"
# Fixing numeric feature: BsmtFin SF 2 	by replacing missing values with median:	 0.0
# Fixing numeric feature: Bsmt Unf SF 	by replacing missing values with median:	 466.0
# Fixing numeric feature: Total Bsmt SF 	by replacing missing values with median:	 990.0
# Fixing categorical feature:	 Electrical 	by replacing missing values with label "missing"
# Fixing numeric feature: Bsmt Full Bath 	by replacing missing values with median:	 0.0
# Fixing numeric feature: Bsmt Half Bath 	by replacing missing values with median:	 0.0
# Fixing categorical feature:	 Fireplace Qu 	by replacing missing values with label "missing"
# Fixing categorical feature:	 Garage Type 	by replacing missing values with label "missing"
# Fixing numeric feature: Garage Yr Blt 	by replacing missing values with median:	 1979.0
# Fixing categorical feature:	 Garage Finish 	by replacing missing values with label "missing"
# Fixing numeric feature: Garage Cars 	by replacing missing values with median:	 2.0
# Fixing numeric feature: Garage Area 	by replacing missing values with median:	 480.0
# Fixing categorical feature:	 Garage Qual 	by replacing missing values with label "missing"
# Fixing categorical feature:	 Garage Cond 	by replacing missing values with label "missing"
# Fixing categorical feature:	 Pool QC 	by replacing missing values with label "missing"
# Fixing categorical feature:	 Fence 	by replacing missing values with label "missing"
# Fixing categorical feature:	 Misc Feature 	by replacing missing values with label "missing"

# %%
#
# Check each feature in list 'incomp_feat' and print datatype and number of missing values
#
for column in incomp_feat:
    print('Column\t', column, '\thas dataype', df[column].dtype,'\tand has', df.shape[0]-df[column].count(),'missing values')
# Out:
# Column	 Lot Frontage 	has dataype float64 	and has 0 missing values
# Column	 Alley 	has dataype category 	and has 0 missing values
# Column	 Mas Vnr Type 	has dataype category 	and has 0 missing values
# Column	 Mas Vnr Area 	has dataype float64 	and has 0 missing values
# Column	 Bsmt Qual 	has dataype category 	and has 0 missing values
# Column	 Bsmt Cond 	has dataype category 	and has 0 missing values
# Column	 Bsmt Exposure 	has dataype category 	and has 0 missing values
# Column	 BsmtFin Type 1 	has dataype category 	and has 0 missing values
# Column	 BsmtFin SF 1 	has dataype float64 	and has 0 missing values
# Column	 BsmtFin Type 2 	has dataype category 	and has 0 missing values
# Column	 BsmtFin SF 2 	has dataype float64 	and has 0 missing values
# Column	 Bsmt Unf SF 	has dataype float64 	and has 0 missing values
# Column	 Total Bsmt SF 	has dataype float64 	and has 0 missing values
# Column	 Electrical 	has dataype category 	and has 0 missing values
# Column	 Bsmt Full Bath 	has dataype float64 	and has 0 missing values
# Column	 Bsmt Half Bath 	has dataype float64 	and has 0 missing values
# Column	 Fireplace Qu 	has dataype category 	and has 0 missing values
# Column	 Garage Type 	has dataype category 	and has 0 missing values
# Column	 Garage Yr Blt 	has dataype float64 	and has 0 missing values
# Column	 Garage Finish 	has dataype category 	and has 0 missing values
# Column	 Garage Cars 	has dataype float64 	and has 0 missing values
# Column	 Garage Area 	has dataype float64 	and has 0 missing values
# Column	 Garage Qual 	has dataype category 	and has 0 missing values
# Column	 Garage Cond 	has dataype category 	and has 0 missing values
# Column	 Pool QC 	has dataype category 	and has 0 missing values
# Column	 Fence 	has dataype category 	and has 0 missing values
# Column	 Misc Feature 	has dataype category 	and has 0 missing values

# %% [markdown]
# # Exercise nr 3

# %% [markdown]
# ###  Exploring Y 'SalePrice' - Descriptive/summary statistics (e.g. mean, SDs, range)

# %%
df['SalePrice'].describe()
# Out:
# count      2930.000000
# mean     180796.060068
# std       79886.692357
# min       12789.000000
# 25%      129500.000000
# 50%      160000.000000
# 75%      213500.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### Visualize the distribution of Sales Price  Y

# %%
#
# Histogram plot of SalePrice showing skew and long tail (high kurtosis). Candidate for log transform
#
df['SalePrice'].hist(bins=100, rwidth=.8, figsize=(16,6))
print ('\nSaleprice skew is :\t', df['SalePrice'].skew())
print ('\nSaleprice kurtosis is :\t', df['SalePrice'].kurtosis())
# Out:
# Saleprice skew is :	 1.7435000757376466
#
# Saleprice kurtosis is :	 5.118899951130896

# %%
#
# Calculating Log transforbm of SalePrice
#
log_saleprice = np.log1p(df["SalePrice"])

# %%
#
# Histogram plot of SalePrice showing lower skew and shorter tail. 
#
log_saleprice.hist(bins=100, rwidth=.8, figsize=(16,6))
print ('\nLog(Saleprice) skew is :\t', log_saleprice.skew())
print ('\nLog(Saleprice) kurtosis is :\t', log_saleprice.kurtosis())
# Out:
# Log(Saleprice) skew is :	 -0.014772659537224368
#
# Log(Saleprice) kurtosis is :	 1.5138180928006526

# %% [markdown]
# ### Visualize the distribution of Sales Price  Y by looking at various subgroups

# %%
#
# Pandas Scatter Matrix plot for features 'Overall Qual','Overall Cond','Gr Liv Area' against 'SalePrice'
#
pd.plotting.scatter_matrix(df[['SalePrice','Overall Qual','Overall Cond','Gr Liv Area']], alpha=0.2, figsize=(12, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E60780A370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E60696E820>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E607620370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E60435A8B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E6069240A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E604381F70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E604381D90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E607790100>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E6061AF700>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E606ECCCA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E607AB1820>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E607A78B50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E60775E130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E607AB94C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E606EB1AC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E60798FFA0>]],
#       dtype=object)

# %%
#
# Seaborn pairplot for features 'Overall Qual','Overall Cond','Gr Liv Area' against 'SalePrice'
#
sns.pairplot(df[['SalePrice','Overall Qual','Overall Cond','Gr Liv Area']])

# %% [markdown]
# ### Look at differences between neigbourhoods

# %%
#
# Box & Swarm plot for SalePrice vs Neighborhood - sorted by median SalePrice
#

# Determine the order of boxes & swarms and store in a list
nbh_median_order = list(df.groupby("Neighborhood")["SalePrice"].median().sort_values(ascending=True).index)

# Set figure size for box plot
plt.figure(figsize=(16, 6))

# Create ordered box plot 
g = sns.boxplot(x="Neighborhood", y="SalePrice", data=df, order=nbh_median_order)

# Set the plot title
g.set_title("Neighborhood vs SalePrice Box Plot - sorted by median")

# Extract the x-axis labels to plot them at an angle to make them readable
xlabels = g.get_xticklabels()
g.set_xticklabels(xlabels,rotation=60)
None # prevent the list of label objects printing annoyingly in the standard output

# Set figure size for swarm plot
plt.figure(figsize=(16, 6))

# Create ordered swarm plot 
h = sns.swarmplot(x="Neighborhood", y="SalePrice", data=df, order=nbh_median_order)

# Set the plot title
h.set_title("Neighborhood vs SalePrice Swarm Plot - sorted by median")

# Plot same x-axis labelsat an angle to make them readable
h.set_xticklabels(xlabels,rotation=60)
None # prevent the list of label objects showing up annoyingly in the output

# %% [markdown]
# ### Look at differences between housing styles

# %%
#
# Box & Swarm plot for SalePrice vs Housing style - sorted by median SalePrice
#

# Determine the order of boxes & swarms and store in a list
hss_median_order = list(df.groupby("House Style")["SalePrice"].median().sort_values(ascending=True).index)

# Set figure size for box plot
plt.figure(figsize=(16, 6))

# Create ordered box plot 
g = sns.boxplot(x="House Style", y="SalePrice", data=df, order=hss_median_order)

# Set the plot title
g.set_title("House Style vs SalePrice Box Plot - sorted by median")

# Set figure size for swarm plot
plt.figure(figsize=(16, 6))

# Create ordered swarm plot 
h = sns.swarmplot(x="House Style", y="SalePrice", data=df, order=hss_median_order)

# Set the plot title
h.set_title("House Style vs SalePrice Swarm Plot - sorted by median")
# Out:
# Text(0.5, 1.0, 'House Style vs SalePrice Swarm Plot - sorted by median')

# %% [markdown]
# ### Draw a heat map and correlation plot to see all correlations between Y and the top 8 independent (numeric) variables

# %%
#
# Calculating and plotting a correlation matrix 
#

# Calculating the correlation matrix 
corr_matrix = df[num_feat].corr()

# Set figure size for heatmap plot
plt.figure(figsize=(16, 12))

# Create a seaborn heatmap plot
g = sns.heatmap(corr_matrix, annot=False,linewidths=.5)

# Set the plot title
g.set_title("Heatmap of all numeric features")
# Out:
# Text(0.5, 1.0, 'Heatmap of all numeric features')

# %%
#
#  Print sorted table of correlations with SalePrice
#
print('Sorted correlations of all numeric features with SalePrice')
corr_matrix.iloc[-1,:].sort_values(ascending=False)
# Out:
# Sorted correlations of all numeric features with SalePrice
# SalePrice          1.000000
# Overall Qual       0.799262
# Gr Liv Area        0.706780
# Garage Cars        0.647812
# Garage Area        0.640381
# Total Bsmt SF      0.632164
# 1st Flr SF         0.621676
# Year Built         0.558426
# Full Bath          0.545604
# Year Remod/Add     0.532974
# Garage Yr Blt      0.508882
# Mas Vnr Area       0.502196
# TotRms AbvGrd      0.495474
# Fireplaces         0.474558
# BsmtFin SF 1       0.432862
# Lot Frontage       0.340256
# Wood Deck SF       0.327143
# Open Porch SF      0.312951
# Half Bath          0.285056
# Bsmt Full Bath     0.275823
# 2nd Flr SF         0.269373
# Lot Area           0.266549
# Bsmt Unf SF        0.182895
# Bedroom AbvGr      0.143913
# Screen Porch       0.112151
# Pool Area          0.068403
# Mo Sold            0.035259
# 3Ssn Porch         0.032225
# BsmtFin SF 2       0.006018
# Misc Val          -0.015691
# Yr Sold           -0.030569
# Bsmt Half Bath    -0.035817
# Low Qual Fin SF   -0.037660
# MS SubClass       -0.085092
# Overall Cond      -0.101697
# Kitchen AbvGr     -0.119814
# Enclosed Porch    -0.128787
# Name: SalePrice, dtype: float64

# %%
#
# Calculating and plotting of a correlation matrix for selected features
#

# Calculating the correlation matrix 
corr_matrix_zoom = df[['Overall Qual','Gr Liv Area','Total Bsmt SF','1st Flr SF','Garage Yr Blt', 'Garage Area','Garage Cars','Year Built', 'SalePrice']].corr()

# Set figure size for heatmap plot
plt.figure(figsize=(16, 12))

# Create a seaborn heatmap plot
g = sns.heatmap(corr_matrix_zoom, annot=True, fmt='.2f', linewidths=.5)

# Set the plot title
g.set_title("Heatmap of selected numeric features")
# Out:
# Text(0.5, 1.0, 'Heatmap of selected numeric features')

# %% [markdown]
# ### Investigating Multicollinearity between numeric features
#
# See https://www.analyticsvidhya.com/blog/2020/03/what-is-multicollinearity/ for example

# %%
#
# Import libraries for VIF, Mapping and define a function to calculate the variance_inflation_factor to 
# determine multicollinearity
#
# VIF starts at 1 and has no upper limit
# VIF = 1, no correlation between the independent feature and other features
# VIF exceeding 5 or 10 indicates high multicollinearity between a feature and other features
#
from statsmodels.stats.outliers_influence import variance_inflation_factor
from collections import Mapping

def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["Feature"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)
# Out:
# C:\Users\jcdek\anaconda3\lib\site-packages\patsy\constraint.py:13: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   from collections import Mapping

# %%
#
# Prepare dataframe with all numeric features without SalePrice and calcuate VIZ matrix
#

# Switch off warnings to avoid annoying warnings
warnings.filterwarnings('ignore')

# Create new feature list 'viz_feat' for VIZ calculations
viz_feat = num_feat.copy()

# Remove SalePrice from viz_feat list if it is present
if 'SalePrice' in viz_feat:
    viz_feat.remove('SalePrice')
    
# Create new dataframe X 
X = df[viz_feat]

# Calculate and sort variance inflation factor for all selected features
vif_matrix = calc_vif(X).sort_values(by=['VIF'], ascending=False)

# Force 'unscientific' formatting of VIF 
pd.options.display.float_format = '{:.2f}'.format

# Print dataframe without distracting index. N.B. VIF > 5 indicates high multi-collinearity
print(vif_matrix.to_string(index=False))

# Store all feaure names with VIF > 5.0 in list 'viz_feat'
vif_feat = vif_matrix[vif_matrix['VIF'] > 5.0].iloc[:,0]

# Switch on warnings again
warnings.filterwarnings('default')
# Out:
#          Feature       VIF
#      Gr Liv Area       inf
#  Low Qual Fin SF       inf
#       2nd Flr SF       inf
#       1st Flr SF       inf
#    Total Bsmt SF 161612.60
#      Bsmt Unf SF  62911.09
#     BsmtFin SF 1  50176.15
#          Yr Sold  23031.89
#   Year Remod/Add  22059.09
#    Garage Yr Blt  20726.51
#       Year Built  20293.75
#     BsmtFin SF 2   3865.18
#    TotRms AbvGrd     78.67
#     Overall Qual     62.50
#     Overall Cond     40.08
#    Kitchen AbvGr     38.90
#      Garage Cars     37.38
#      Garage Area     33.02
#    Bedroom AbvGr     30.21
#        Full Bath     25.30
#     Lot Frontage     18.56
#          Mo Sold      6.34
#      MS SubClass      4.60
#   Bsmt Full Bath      3.59
#         Lot Area      3.44
#        Half Bath      3.37
#       Fireplaces      2.90
#     Wood Deck SF      1.91
#     Mas Vnr Area      1.87
#    Open Porch SF      1.83
#   Enclosed Porch      1.40
#   Bsmt Half Bath      1.24
#     Screen Porch      1.17
#        Pool Area      1.09
#         Misc Val      1.06
#       3Ssn Porch      1.03

# %%
#
# Show statistics of features with VIF > 5
#
df[vif_feat].describe().transpose()
# Out:
#                   count    mean    std     min     25%     50%     75%     max
# Gr Liv Area     2930.00 1499.69 505.51  334.00 1126.00 1442.00 1742.75 5642.00
# Low Qual Fin SF 2930.00    4.68  46.31    0.00    0.00    0.00    0.00 1064.00
# 2nd Flr SF      2930.00  335.46 428.40    0.00    0.00    0.00  703.75 2065.00
# 1st Flr SF      2930.00 1159.56 391.89  334.00  876.25 1084.00 1384.00 5095.00
# Total Bsmt SF   2930.00 1051.59 440.54    0.00  793.00  990.00 1301.50 6110.00
# Bsmt Unf SF     2930.00  559.23 439.42    0.00  219.00  466.00  801.75 2336.00
# BsmtFin SF 1    2930.00  442.60 455.52    0.00    0.00  370.00  734.00 5644.00
# Yr Sold         2930.00 2007.79   1.32 2006.00 2007.00 2008.00 2009.00 2010.00
# Year Remod/Add  2930.00 1984.27  20.86 1950.00 1965.00 1993.00 2004.00 2010.00
# Garage Yr Blt   2930.00 1978.18  24.83 1895.00 1962.00 1979.00 2001.00 2207.00
# Year Built      2930.00 1971.36  30.25 1872.00 1954.00 1973.00 2001.00 2010.00
# BsmtFin SF 2    2930.00   49.71 169.14    0.00    0.00    0.00    0.00 1526.00
# TotRms AbvGrd   2930.00    6.44   1.57    2.00    5.00    6.00    7.00   15.00
# Overall Qual    2930.00    6.09   1.41    1.00    5.00    6.00    7.00   10.00
# Overall Cond    2930.00    5.56   1.11    1.00    5.00    5.00    6.00    9.00
# Kitchen AbvGr   2930.00    1.04   0.21    0.00    1.00    1.00    1.00    3.00
# Garage Cars     2930.00    1.77   0.76    0.00    1.00    2.00    2.00    5.00
# Garage Area     2930.00  472.82 215.01    0.00  320.00  480.00  576.00 1488.00
# Bedroom AbvGr   2930.00    2.85   0.83    0.00    2.00    3.00    3.00    8.00
# Full Bath       2930.00    1.57   0.55    0.00    1.00    2.00    2.00    4.00
# Lot Frontage    2930.00   69.02  21.33   21.00   60.00   68.00   78.00  313.00
# Mo Sold         2930.00    6.22   2.71    1.00    4.00    6.00    8.00   12.00

# %%
#
# Calculating and plotting a correlation matrix of the top 4 numeric features with highest correlation with SalePrice
#

# Calculating a list of sorted correlation values 
sorted_corr_list = list(corr_matrix.iloc[-1,:].sort_values(ascending=False).index)

# Seaborn pairplot of correlations
g = sns.pairplot(df[sorted_corr_list[0:5]])

# Set the plot title
plt.subplots_adjust(top=0.95)
g.fig.suptitle('Correlation map of top 4 numeric features with SalePrice')
None

# %%
#
# Calculating and plotting a correlation matrix of the numeric features with correlation 5 - 8 with SalePrice
#

# Calculating a list of sorted correlation values 
sorted_corr_list = list(corr_matrix.iloc[-1,:].sort_values(ascending=False).index)

# Delete top 4 list elements.First element 'SalePrice' will remain
del sorted_corr_list[1:5]

# Seaborn pairplot of correlations
g = sns.pairplot(df[sorted_corr_list[0:5]])

# Set the plot title
plt.subplots_adjust(top=0.95)
g.fig.suptitle('Correlation map of numeric features 5-8 with SalePrice')
None

# %% [markdown]
# ### Next is feature engineering including log transform of features with skew > 0.75, combining features, creation of dummies
